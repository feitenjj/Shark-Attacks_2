# %%
import pandas as pd

# %%
# !pip install xlrd
# Out:
# Requirement already satisfied: xlrd in /usr/local/lib/python3.12/dist-packages (2.0.2)

# %%
df = pd.read_excel("https://www.sharkattackfile.net/spreadsheets/GSAF5.xls")

# %%
df.head()
# Out:
#                Date    Year        Type      Country  \
# 0  16th August 2025  2025.0    Provoked          USA
# 1       18th August  2025.0  Unprovoked    Australia
# 2       17th August  2025.0  Unprovoked      Bahamas
# 3        7th August  2025.0  Unprovoked    Australia
# 4        1st August  2025.0  Unprovoked  Puerto Rico
#
#                                State                             Location  \
# 0                            Florida               Cayo Costa Boca Grande
# 1                                NSW                       Cabarita Beach
# 2  Atlantic Ocean near Big Grand Cay  North of Grand Bahama near Freeport
# 3                                NSW                        Tathra Beach
# 4                           Carolina                       Carolina Beach
#
#        Activity          Name Sex Age  ...                 Species   \
# 0       Fishing   Shawn Meuse   M   ?  ...  Lemon shark 1.8 m (6ft)
# 1       Surfing     Brad Ross   M   ?  ...  5m (16.5ft) Great White
# 2  Spearfishing    Not stated   M  63  ...             Undetermined
# 3       Surfing   Bowie Daley   M   9  ...    Suspected Great White
# 4        Wading  Eleonora Boi   F  39  ...             Undetermined
#
#                                               Source  pdf href formula href  \
# 0  Johannes Marchand: Kevin McMurray Trackingshar...  NaN          NaN  NaN
# 1  Bob Myatt GSAF The Guardian: 9 News: ABS News:...  NaN          NaN  NaN
# 2  Ralph Collier GSAF and Kevin MCMurray Tracking...  NaN          NaN  NaN
# 3                                     Bob Myatt GSAF  NaN          NaN  NaN
# 4         Kevin McMurray Trackingsharks.com: NY Post  NaN          NaN  NaN
#
#   Case Number Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0         NaN           NaN            NaN         NaN         NaN
# 1         NaN           NaN            NaN         NaN         NaN
# 2         NaN           NaN            NaN         NaN         NaN
# 3         NaN           NaN            NaN         NaN         NaN
# 4         NaN           NaN            NaN         NaN         NaN
#
# [5 rows x 23 columns]

# %%
# Count the number of null values in each column
df.isna().sum()
# Out:
# Date                 0
# Year                 2
# Type                18
# Country             50
# State              485
# Location           567
# Activity           585
# Name               219
# Sex                579
# Age               2994
# Injury              35
# Fatal Y/N          561
# Time              3526
# Species           3131
# Source              20
# pdf                243
# href formula       248
# href               246
# Case Number        244
# Case Number.1      245
# original order     243
# Unnamed: 21       7041
# Unnamed: 22       7040
# dtype: int64

# %%
 #Checking shape.
 df.shape #rows and columns
# Out:
# (7042, 23)

# %%
#Checking for duplicates.
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Checking for duplicates.
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7037    False
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# Length: 7042, dtype: bool

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
#Converting Country column to uppercase.
df['Country'] = df['Country'].str.upper()
df
# Out:
#                   Date    Year        Type             Country  \
# 0     16th August 2025  2025.0    Provoked                 USA
# 1          18th August  2025.0  Unprovoked           AUSTRALIA
# 2          17th August  2025.0  Unprovoked             BAHAMAS
# 3           7th August  2025.0  Unprovoked           AUSTRALIA
# 4           1st August  2025.0  Unprovoked         PUERTO RICO
# ...                ...     ...         ...                 ...
# 7037       Before 1903     0.0  Unprovoked           AUSTRALIA
# 7038       Before 1903     0.0  Unprovoked           AUSTRALIA
# 7039         1900-1905     0.0  Unprovoked                 USA
# 7040         1883-1889     0.0  Unprovoked              PANAMA
# 7041         1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                                   State                             Location  \
# 0                               Florida               Cayo Costa Boca Grande
# 1                                   NSW                       Cabarita Beach
# 2     Atlantic Ocean near Big Grand Cay  North of Grand Bahama near Freeport
# 3                                   NSW                        Tathra Beach
# 4                              Carolina                       Carolina Beach
# ...                                 ...                                  ...
# 7037                  Western Australia                          Roebuck Bay
# 7038                  Western Australia                                  NaN
# 7039                     North Carolina                       Ocracoke Inlet
# 7040                                NaN                 Panama Bay 8ºN, 79ºW
# 7041                   Eastern Province  Below the English fort, Trincomalee
#
#           Activity                   Name Sex  Age  ...  \
# 0          Fishing            Shawn Meuse   M    ?  ...
# 1          Surfing              Brad Ross   M    ?  ...
# 2     Spearfishing             Not stated   M   63  ...
# 3          Surfing            Bowie Daley   M    9  ...
# 4           Wading           Eleonora Boi   F   39  ...
# ...            ...                    ...  ..  ...  ...
# 7037        Diving                   male   M  NaN  ...
# 7038  Pearl diving                  Ahmun   M  NaN  ...
# 7039      Swimming  Coast Guard personnel   M  NaN  ...
# 7040           NaN        Jules Patterson   M  NaN  ...
# 7041      Swimming                   male   M   15  ...
#
#                      Species   \
# 0     Lemon shark 1.8 m (6ft)
# 1     5m (16.5ft) Great White
# 2                Undetermined
# 3       Suspected Great White
# 4                Undetermined
# ...                       ...
# 7037                      NaN
# 7038                      NaN
# 7039                      NaN
# 7040                      NaN
# 7041                      NaN
#
#                                                  Source  \
# 0     Johannes Marchand: Kevin McMurray Trackingshar...
# 1     Bob Myatt GSAF The Guardian: 9 News: ABS News:...
# 2     Ralph Collier GSAF and Kevin MCMurray Tracking...
# 3                                        Bob Myatt GSAF
# 4            Kevin McMurray Trackingsharks.com: NY Post
# ...                                                 ...
# 7037                   H. Taunton; N. Bartlett,  p. 234
# 7038              H. Taunton; N. Bartlett,  pp. 233-234
# 7039               F. Schwartz, p.23; C. Creswell, GSAF
# 7040                                The Sun, 10/20/1938
# 7041                                         S.W. Baker
#
#                                  pdf  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 7037          ND-0005-RoebuckBay.pdf
# 7038               ND-0004-Ahmun.pdf
# 7039  ND-0003-Ocracoke_1900-1905.pdf
# 7040      ND-0002-JulesPatterson.pdf
# 7041              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 7037  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7038  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7039  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7040  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7041  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 7037  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0005
# 7038  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0004
# 7039  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0003
# 7040  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0002
# 7041  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0001
#
#      Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0              NaN            NaN         NaN         NaN
# 1              NaN            NaN         NaN         NaN
# 2              NaN            NaN         NaN         NaN
# 3              NaN            NaN         NaN         NaN
# 4              NaN            NaN         NaN         NaN
# ...            ...            ...         ...         ...
# 7037       ND.0005            6.0         NaN         NaN
# 7038       ND.0004            5.0         NaN         NaN
# 7039       ND.0003            4.0         NaN         NaN
# 7040       ND.0002            3.0         NaN         NaN
# 7041       ND.0001            2.0         NaN         NaN
#
# [7042 rows x 23 columns]

# %%
# Checking if USA is the only way the country was written, as we are going to work with USA
country_list = sorted([c for c in df['Country'].unique() if isinstance(c, str)])
print(country_list)
# Out:
# [' PHILIPPINES', ' TONGA', 'ADMIRALTY ISLANDS', 'AFRICA', 'ALGERIA', 'AMERICAN SAMOA', 'ANDAMAN / NICOBAR ISLANDAS', 'ANDAMAN ISLANDS', 'ANGOLA', 'ANTIGUA', 'ARGENTINA', 'ARUBA', 'ASIA?', 'ATLANTIC OCEAN', 'AUSTRALIA', 'AZORES', 'BAHAMAS', 'BAHREIN', 'BANGLADESH', 'BARBADOS', 'BAY OF BENGAL', 'BELIZE', 'BERMUDA', 'BETWEEN PORTUGAL & INDIA', 'BRAZIL', 'BRITISH ISLES', 'BRITISH NEW GUINEA', 'BRITISH OVERSEAS TERRITORY', 'BRITISH VIRGIN ISLANDS', 'BRITISH WEST INDIES', 'BURMA', 'CANADA', 'CANARY ISLANDS', 'CAPE VERDE', 'CARIBBEAN SEA', 'CAYMAN ISLANDS', 'CENTRAL PACIFIC', 'CEYLON', 'CEYLON (SRI LANKA)', 'CHILE', 'CHINA', 'COAST OF AFRICA', 'COLOMBIA', 'COLUMBIA', 'COMOROS', 'COOK ISLANDS', 'CORAL SEA', 'COSTA RICA', 'CRETE', 'CROATIA', 'CUBA', 'CURACAO', 'CYPRUS', 'DIEGO GARCIA', 'DJIBOUTI', 'DOMINICAN REPUBLIC', 'ECUADOR', 'EGYPT', 'EGYPT ', 'EGYPT / ISRAEL', 'EL SALVADOR', 'ENGLAND', 'EQUATORIAL GUINEA / CAMEROON', 'FALKLAND ISLANDS', 'FEDERATED STATES OF MICRONESIA', 'FIJI', 'FRANCE', 'FRENCH POLYNESIA', 'GABON', 'GEORGIA', 'GHANA', 'GRAND CAYMAN', 'GREECE', 'GREENLAND', 'GRENADA', 'GUAM', 'GUATEMALA', 'GUINEA', 'GULF OF ADEN', 'GUYANA', 'HAITI', 'HAWAII', 'HONDURAS', 'HONG KONG', 'ICELAND', 'INDIA', 'INDIAN OCEAN', 'INDIAN OCEAN?', 'INDONESIA', 'IRAN', 'IRAN / IRAQ', 'IRAQ', 'IRELAND', 'ISRAEL', 'ITALY', 'ITALY / CROATIA', 'JAMAICA', 'JAPAN', 'JAVA', 'JOHNSTON ISLAND', 'JORDAN', 'KENYA', 'KIRIBATI', 'KOREA', 'KUWAIT', 'LEBANON', 'LIBERIA', 'LIBYA', 'MADAGASCAR', 'MALAYSIA', 'MALDIVE ISLANDS', 'MALDIVES', 'MALTA', 'MARSHALL ISLANDS', 'MARTINIQUE', 'MAURITIUS', 'MAYOTTE', 'MEDITERRANEAN SEA', 'MEXICO', 'MEXICO ', 'MICRONESIA', 'MID ATLANTIC OCEAN', 'MID-PACIFC OCEAN', 'MONACO', 'MONTENEGRO', 'MOROCCO', 'MOZAMBIQUE', 'NAMIBIA', 'NETHERLANDS ANTILLES', 'NEVIS', 'NEW BRITAIN', 'NEW CALEDONIA', 'NEW GUINEA', 'NEW ZEALAND', 'NICARAGUA', 'NICARAGUA ', 'NIGERIA', 'NORTH ATLANTIC OCEAN', 'NORTH ATLANTIC OCEAN ', 'NORTH PACIFIC OCEAN', 'NORTH SEA', 'NORTHERN ARABIAN SEA', 'NORTHERN MARIANA ISLANDS', 'NORWAY', 'OCEAN', 'OKINAWA', 'PACIFIC OCEAN', 'PACIFIC OCEAN ', 'PALAU', 'PALESTINIAN TERRITORIES', 'PANAMA', 'PAPUA NEW GUINEA', 'PARAGUAY', 'PERSIAN GULF', 'PERU', 'PHILIPPINES', 'PORTUGAL', 'PUERTO RICO', 'RED SEA', 'RED SEA / INDIAN OCEAN', 'RED SEA?', 'REUNION', 'REUNION ISLAND', 'ROATAN', 'RUSSIA', 'SAMOA', 'SAN DOMINGO', 'SAUDI ARABIA', 'SCOTLAND', 'SENEGAL', 'SEYCHELLES', 'SIERRA LEONE', 'SINGAPORE', 'SLOVENIA', 'SOLOMON ISLANDS', 'SOLOMON ISLANDS / VANUATU', 'SOMALIA', 'SOUTH AFRICA', 'SOUTH ATLANTIC OCEAN', 'SOUTH CHINA SEA', 'SOUTH KOREA', 'SOUTH PACIFIC OCEAN', 'SOUTHWEST PACIFIC OCEAN', 'SPAIN', 'SRI LANKA', 'ST HELENA, BRITISH OVERSEAS TERRITORY', 'ST KITTS / NEVIS', 'ST MARTIN', 'ST. MAARTIN', 'ST. MARTIN', 'SUDAN', 'SUDAN?', 'SWEDEN', 'SYRIA', 'TAIWAN', 'TANZANIA', 'TASMAN SEA', 'THAILAND', 'THE BALKANS', 'TOBAGO', 'TONGA', 'TRINIDAD', 'TRINIDAD & TOBAGO', 'TUNISIA', 'TURKEY', 'TURKS & CAICOS', 'TURKS AND CAICOS', 'TUVALU', 'UNITED ARAB EMIRATES', 'UNITED ARAB EMIRATES (UAE)', 'UNITED KINGDOM', 'URUGUAY', 'USA', 'VANUATU', 'VENEZUELA', 'VIETNAM', 'WEST INDIES', 'WESTERN SAMOA', 'YEMEN', 'YEMEN ']

# %%
df.Country.value_counts()
# Out:
# Country
# USA                   2570
# AUSTRALIA             1507
# SOUTH AFRICA           599
# NEW ZEALAND            146
# BAHAMAS                141
#                       ...
# BAHREIN                  1
# KOREA                    1
# RED SEA?                 1
# ASIA?                    1
# CEYLON (SRI LANKA)       1
# Name: count, Length: 220, dtype: int64

# %%
df.Country.value_counts().sum()
# Out:
# np.int64(6992)

# %%
# Filters the dataframe with only USA attacks.
usa_filtered_df = df[df['Country'].str.strip().str.upper() == "USA"]
usa_filtered_df
# Out:
#                     Date    Year        Type Country            State  \
# 0       16th August 2025  2025.0    Provoked     USA          Florida
# 9              19th July  2025.0  Unprovoked     USA          Florida
# 10             18th July  2025.0  Unprovoked     USA          Florida
# 12             6th July   2025.0    Provoked     USA    Massachusetts
# 13              6th July  2025.0  Unprovoked     USA          Florida
# ...                  ...     ...         ...     ...              ...
# 6989         Before 1958     0.0  Unprovoked     USA          Florida
# 7023         Before 1921     0.0  Unprovoked     USA          Florida
# 7028  Before 17-Jul-1916     0.0  Unprovoked     USA  North Carolina
# 7032          Circa 1862     0.0  Unprovoked     USA           Hawaii
# 7039           1900-1905     0.0  Unprovoked     USA   North Carolina
#
#                                                Location  Activity  \
# 0                                Cayo Costa Boca Grande   Fishing
# 9     Jupiter Inlet off Jupiter Beach Palm Beach County    Diving
# 10                                     New Smyrna Beach   Surfing
# 12                        Hoicks Hollow Nantucket Beach   Fishing
# 13                                     New Smyrna Beach   Surfing
# ...                                                 ...       ...
# 6989                      Palm Beach, Palm Beach County  Standing
# 7023                           Gadsden Point, Tampa Bay   Fishing
# 7028            Somewhere between Hatteras and Beaufort  Swimming
# 7032                                               Puna       NaN
# 7039                                     Ocracoke Inlet  Swimming
#
#                        Name Sex  Age  ...                        Species   \
# 0               Shawn Meuse   M    ?  ...         Lemon shark 1.8 m (6ft)
# 9                 Jeff Joel   M   69  ...                     Lemon shark
# 10               Sam Hollis   M   18  ...                    Undetermined
# 12             Unknown Male   M   21  ...                         Unknown
# 13             Unknown Male   M   40  ...  Undetermined small shall shark
# ...                     ...  ..  ...  ...                             ...
# 6989           Horton Chase   M  NaN  ...                             NaN
# 7023           James Kelley   M  NaN  ...                             NaN
# 7028        "youthful male"   M  NaN  ...                             NaN
# 7032           A "chiefess"   F  NaN  ...                             NaN
# 7039  Coast Guard personnel   M  NaN  ...                             NaN
#
#                                                  Source  \
# 0     Johannes Marchand: Kevin McMurray Trackingshar...
# 9     Brandyn Gartelman: Kevin McMurray Trackingshar...
# 10    Brandyn Gartelman: Kevin McMurray Trackingshar...
# 12                 Johannes Marchand: Nantucket Current
# 13    Todd Smith:Kevin McMurray Trackingsharks.com: ...
# ...                                                 ...
# 6989         V.M. Coppleson (1956), p.255;  R.F. Hutton
# 7023                                     T. Helm, p.219
# 7028     C. Creswell, GSAF; Wilmington Star, 7/17/1916
# 7032                                   Captain W. Young
# 7039               F. Schwartz, p.23; C. Creswell, GSAF
#
#                                     pdf  \
# 0                                   NaN
# 9                                   NaN
# 10                                  NaN
# 12                                  NaN
# 13                                  NaN
# ...                                 ...
# 6989            ND-0056-HortonChase.pdf
# 7023                 ND-0019-Kelley.pdf
# 7028  ND-0014-pre1916-NorthCarolina.pdf
# 7032            ND-0010-Puna Hawaii.pdf
# 7039     ND-0003-Ocracoke_1900-1905.pdf
#
#                                            href formula  \
# 0                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# ...                                                 ...
# 6989  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7023  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7028  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7032  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7039  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number  \
# 0                                                   NaN         NaN
# 9                                                   NaN         NaN
# 10                                                  NaN         NaN
# 12                                                  NaN         NaN
# 13                                                  NaN         NaN
# ...                                                 ...         ...
# 6989  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0056
# 7023  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0019
# 7028  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0014
# 7032  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0010
# 7039  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0003
#
#      Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0              NaN            NaN         NaN         NaN
# 9              NaN            NaN         NaN         NaN
# 10             NaN            NaN         NaN         NaN
# 12             NaN            NaN         NaN         NaN
# 13             NaN            NaN         NaN         NaN
# ...            ...            ...         ...         ...
# 6989       ND.0056           54.0         NaN         NaN
# 7023       ND.0019           20.0         NaN         NaN
# 7028       ND.0014           15.0         NaN         NaN
# 7032       ND.0010           11.0         NaN         NaN
# 7039       ND.0003            4.0         NaN         NaN
#
# [2570 rows x 23 columns]

# %%
#Cleans the state names.
usa_filtered_df["State"] = usa_filtered_df["State"].str.replace(r'^"|"$', '', regex=True).str.strip()
usa_filtered_df["State"] = usa_filtered_df["State"].str.replace(r"\s*,\s*", '', regex=True).str.strip()
usa_filtered_df["State"]
# Out:
# /tmp/ipython-input-2365884150.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_filtered_df["State"] = usa_filtered_df["State"].str.replace(r'^"|"$', '', regex=True).str.strip()
# /tmp/ipython-input-2365884150.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_filtered_df["State"] = usa_filtered_df["State"].str.replace(r"\s*,\s*", '', regex=True).str.strip()
# 0              Florida
# 9              Florida
# 10             Florida
# 12       Massachusetts
# 13             Florida
#              ...
# 6989           Florida
# 7023           Florida
# 7028    North Carolina
# 7032            Hawaii
# 7039    North Carolina
# Name: State, Length: 2570, dtype: object

# %%
#Cleans the activity names.
usa_filtered_df["Activity"] = usa_filtered_df["Activity"].str.replace(r'^"|"$', '', regex=True).str.strip()
usa_filtered_df["Activity"] = usa_filtered_df["Activity"].str.replace(r"\s*,\s*", '', regex=True).str.strip()
usa_filtered_df["Activity"]
# Out:
# /tmp/ipython-input-3274959366.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_filtered_df["Activity"] = usa_filtered_df["Activity"].str.replace(r'^"|"$', '', regex=True).str.strip()
# /tmp/ipython-input-3274959366.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_filtered_df["Activity"] = usa_filtered_df["Activity"].str.replace(r"\s*,\s*", '', regex=True).str.strip()
# 0        Fishing
# 9         Diving
# 10       Surfing
# 12       Fishing
# 13       Surfing
#           ...
# 6989    Standing
# 7023     Fishing
# 7028    Swimming
# 7032         NaN
# 7039    Swimming
# Name: Activity, Length: 2570, dtype: object

# %%
#Cleans the location names.
usa_filtered_df["Location"] = usa_filtered_df["Location"].str.replace(r'^"|"$', '', regex=True).str.strip()
usa_filtered_df["Location"] = usa_filtered_df["Location"].str.replace(r"\s*,\s*", ', ', regex=True).str.strip()
usa_filtered_df["Location"]
# Out:
# /tmp/ipython-input-1831302913.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_filtered_df["Location"] = usa_filtered_df["Location"].str.replace(r'^"|"$', '', regex=True).str.strip()
# /tmp/ipython-input-1831302913.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa_filtered_df["Location"] = usa_filtered_df["Location"].str.replace(r"\s*,\s*", ', ', regex=True).str.strip()
# 0                                  Cayo Costa Boca Grande
# 9       Jupiter Inlet off Jupiter Beach Palm Beach County
# 10                                       New Smyrna Beach
# 12                          Hoicks Hollow Nantucket Beach
# 13                                       New Smyrna Beach
#                               ...
# 6989                        Palm Beach, Palm Beach County
# 7023                             Gadsden Point, Tampa Bay
# 7028              Somewhere between Hatteras and Beaufort
# 7032                                                 Puna
# 7039                                       Ocracoke Inlet
# Name: Location, Length: 2570, dtype: object

# %%
#Resets the index numbers after cleaning rows.
usa_filtered_df.reset_index(drop=True, inplace=True)
usa_filtered_df
# Out:
#                     Date    Year        Type Country           State  \
# 0       16th August 2025  2025.0    Provoked     USA         Florida
# 1              19th July  2025.0  Unprovoked     USA         Florida
# 2              18th July  2025.0  Unprovoked     USA         Florida
# 3              6th July   2025.0    Provoked     USA   Massachusetts
# 4               6th July  2025.0  Unprovoked     USA         Florida
# ...                  ...     ...         ...     ...             ...
# 2565         Before 1958     0.0  Unprovoked     USA         Florida
# 2566         Before 1921     0.0  Unprovoked     USA         Florida
# 2567  Before 17-Jul-1916     0.0  Unprovoked     USA  North Carolina
# 2568          Circa 1862     0.0  Unprovoked     USA          Hawaii
# 2569           1900-1905     0.0  Unprovoked     USA  North Carolina
#
#                                                Location  Activity  \
# 0                                Cayo Costa Boca Grande   Fishing
# 1     Jupiter Inlet off Jupiter Beach Palm Beach County    Diving
# 2                                      New Smyrna Beach   Surfing
# 3                         Hoicks Hollow Nantucket Beach   Fishing
# 4                                      New Smyrna Beach   Surfing
# ...                                                 ...       ...
# 2565                      Palm Beach, Palm Beach County  Standing
# 2566                           Gadsden Point, Tampa Bay   Fishing
# 2567            Somewhere between Hatteras and Beaufort  Swimming
# 2568                                               Puna       NaN
# 2569                                     Ocracoke Inlet  Swimming
#
#                        Name Sex  Age  ...                        Species   \
# 0               Shawn Meuse   M    ?  ...         Lemon shark 1.8 m (6ft)
# 1                 Jeff Joel   M   69  ...                     Lemon shark
# 2                Sam Hollis   M   18  ...                    Undetermined
# 3              Unknown Male   M   21  ...                         Unknown
# 4              Unknown Male   M   40  ...  Undetermined small shall shark
# ...                     ...  ..  ...  ...                             ...
# 2565           Horton Chase   M  NaN  ...                             NaN
# 2566           James Kelley   M  NaN  ...                             NaN
# 2567        "youthful male"   M  NaN  ...                             NaN
# 2568           A "chiefess"   F  NaN  ...                             NaN
# 2569  Coast Guard personnel   M  NaN  ...                             NaN
#
#                                                  Source  \
# 0     Johannes Marchand: Kevin McMurray Trackingshar...
# 1     Brandyn Gartelman: Kevin McMurray Trackingshar...
# 2     Brandyn Gartelman: Kevin McMurray Trackingshar...
# 3                  Johannes Marchand: Nantucket Current
# 4     Todd Smith:Kevin McMurray Trackingsharks.com: ...
# ...                                                 ...
# 2565         V.M. Coppleson (1956), p.255;  R.F. Hutton
# 2566                                     T. Helm, p.219
# 2567     C. Creswell, GSAF; Wilmington Star, 7/17/1916
# 2568                                   Captain W. Young
# 2569               F. Schwartz, p.23; C. Creswell, GSAF
#
#                                     pdf  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 2565            ND-0056-HortonChase.pdf
# 2566                 ND-0019-Kelley.pdf
# 2567  ND-0014-pre1916-NorthCarolina.pdf
# 2568            ND-0010-Puna Hawaii.pdf
# 2569     ND-0003-Ocracoke_1900-1905.pdf
#
#                                            href formula  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2565  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2566  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2567  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2568  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2569  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# ...                                                 ...         ...
# 2565  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0056
# 2566  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0019
# 2567  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0014
# 2568  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0010
# 2569  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0003
#
#      Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0              NaN            NaN         NaN         NaN
# 1              NaN            NaN         NaN         NaN
# 2              NaN            NaN         NaN         NaN
# 3              NaN            NaN         NaN         NaN
# 4              NaN            NaN         NaN         NaN
# ...            ...            ...         ...         ...
# 2565       ND.0056           54.0         NaN         NaN
# 2566       ND.0019           20.0         NaN         NaN
# 2567       ND.0014           15.0         NaN         NaN
# 2568       ND.0010           11.0         NaN         NaN
# 2569       ND.0003            4.0         NaN         NaN
#
# [2570 rows x 23 columns]

# %%
#Drops uneeded columns.
usa_filtered_df = usa_filtered_df.drop(columns=["Date", "Year", "Type", "Name", "Sex", "Age",	"Injury", "Time", "Fatal Y/N", "pdf", "Source", "href formula", "href", "Case Number", "Case Number.1", "original order", "Unnamed: 21", "Unnamed: 22"])
usa_filtered_df
# Out:
#      Country           State  \
# 0        USA         Florida
# 1        USA         Florida
# 2        USA         Florida
# 3        USA   Massachusetts
# 4        USA         Florida
# ...      ...             ...
# 2565     USA         Florida
# 2566     USA         Florida
# 2567     USA  North Carolina
# 2568     USA          Hawaii
# 2569     USA  North Carolina
#
#                                                Location  Activity  \
# 0                                Cayo Costa Boca Grande   Fishing
# 1     Jupiter Inlet off Jupiter Beach Palm Beach County    Diving
# 2                                      New Smyrna Beach   Surfing
# 3                         Hoicks Hollow Nantucket Beach   Fishing
# 4                                      New Smyrna Beach   Surfing
# ...                                                 ...       ...
# 2565                      Palm Beach, Palm Beach County  Standing
# 2566                           Gadsden Point, Tampa Bay   Fishing
# 2567            Somewhere between Hatteras and Beaufort  Swimming
# 2568                                               Puna       NaN
# 2569                                     Ocracoke Inlet  Swimming
#
#                             Species
# 0            Lemon shark 1.8 m (6ft)
# 1                        Lemon shark
# 2                       Undetermined
# 3                            Unknown
# 4     Undetermined small shall shark
# ...                              ...
# 2565                             NaN
# 2566                             NaN
# 2567                             NaN
# 2568                             NaN
# 2569                             NaN
#
# [2570 rows x 5 columns]

# %%
#Drops uneeded columns.
usa_filtered_df = usa_filtered_df.drop(columns=["Species "])
usa_filtered_df
# Out:
#      Country           State  \
# 0        USA         Florida
# 1        USA         Florida
# 2        USA         Florida
# 3        USA   Massachusetts
# 4        USA         Florida
# ...      ...             ...
# 2565     USA         Florida
# 2566     USA         Florida
# 2567     USA  North Carolina
# 2568     USA          Hawaii
# 2569     USA  North Carolina
#
#                                                Location  Activity
# 0                                Cayo Costa Boca Grande   Fishing
# 1     Jupiter Inlet off Jupiter Beach Palm Beach County    Diving
# 2                                      New Smyrna Beach   Surfing
# 3                         Hoicks Hollow Nantucket Beach   Fishing
# 4                                      New Smyrna Beach   Surfing
# ...                                                 ...       ...
# 2565                      Palm Beach, Palm Beach County  Standing
# 2566                           Gadsden Point, Tampa Bay   Fishing
# 2567            Somewhere between Hatteras and Beaufort  Swimming
# 2568                                               Puna       NaN
# 2569                                     Ocracoke Inlet  Swimming
#
# [2570 rows x 4 columns]

# %%
# Number of attacks per state in the USA.
usa_filtered_df.State.value_counts()
# Out:
# State
# Florida                   1192
# Hawaii                     344
# California                 325
# South Carolina             175
# North Carolina             122
# Texas                       81
# New Jersey                  57
# New York                    48
# Oregon                      31
# Virginia                    19
# Massachusetts               19
# Louisiana                   18
# Puerto Rico                 17
# Alabama                     17
# Georgia                     17
# Maryland                    10
# Mississippi                  8
# Delaware                     8
# Rhode Island                 8
# Connecticut                  6
# US Virgin Islands            5
# Washington                   2
# Palmyra Atoll                2
# East coast                   2
# Guam                         2
# Maine                        2
# Maui                         2
# Noirth Carolina              1
# Samoa                        1
# Utah                         1
# Galveston                    1
# Floria                       1
# Long Island NY               1
# Los Angeles                  1
# BAHAMAS                      1
# Bahamas                      1
# Cayman Islands               1
# Franklin CountyFlorida       1
# Virgin Islands               1
# Johnston Atoll               1
# Alaska                       1
# Kentucky                     1
# New Mexico                   1
# North & South Carolina       1
# Missouri                     1
# Pennsylvania                 1
# Carolina coast               1
# Illinois                     1
# Wake Island                  1
# Midway Atoll                 1
# CUBA                         1
# Name: count, dtype: int64

# %%
# Number of attacks per location.
usa_filtered_df.Location.value_counts()
# Out:
# Location
# New Smyrna Beach, Volusia County               196
# Daytona Beach, Volusia County                   34
# Ponce Inlet, Volusia County                     28
# Myrtle Beach, Horry County                      22
# Melbourne Beach, Brevard County                 21
#                                               ...
# Will Rogers State Beach, Los Angeles County      1
# Marques Island                                   1
# Atlantic Beach, Carteret County                  1
# Faria Beach, Ventura County                      1
# 100 miles off Ft. Myers Beach                    1
# Name: count, Length: 1535, dtype: int64

# %%
# Number of attacks to surfing.
surf_count = df[df["Activity"] == "Surfing"].shape[0]
surf_count
# Out:
# 1138

# %%
# Filters the dataframe with only attacks to surfing.
surf_count_df = df[df["Activity"] == "Surfing"]
surf_count_df
# Out:
#               Date    Year        Type    Country            State  \
# 1      18th August  2025.0  Unprovoked  AUSTRALIA              NSW
# 3       7th August  2025.0  Unprovoked  AUSTRALIA              NSW
# 10       18th July  2025.0  Unprovoked        USA          Florida
# 13        6th July  2025.0  Unprovoked        USA          Florida
# 20        31st May  2025.0  Unprovoked        USA       California
# ...            ...     ...         ...        ...              ...
# 5963   04-Jan-1922  1922.0  Unprovoked  AUSTRALIA  New South Wales
# 6008   22-Mar-1918  1918.0  Unprovoked  AUSTRALIA  New South Wales
# 6828          1828  1828.0  Unprovoked        USA           Hawaii
# 6875          1779  1779.0  Unprovoked        USA           Hawaii
# 6941  Beforer 1994     0.0  Unprovoked        USA          Florida
#
#                                   Location Activity               Name Sex  \
# 1                           Cabarita Beach  Surfing          Brad Ross   M
# 3                            Tathra Beach   Surfing        Bowie Daley   M
# 10                        New Smyrna Beach  Surfing         Sam Hollis   M
# 13                        New Smyrna Beach  Surfing       Unknown Male   M
# 20                     Montara State Beach  Surfing        Jens Heller   M
# ...                                    ...      ...                ...  ..
# 5963             Stockton Beach, Newcastle  Surfing  John Manning Rowe   M
# 6008                             Newcastle  Surfing        Arthur Cook   M
# 6828                     Uo, Lahaina, Maui  Surfing               Male   M
# 6875                        Maliu, Hawai'i  Surfing   Nu'u-anu-pa'a hu   M
# 6941  Lost Tree Village, Palm Beach County  Surfing                C.M   M
#
#         Age  ...                        Species   \
# 1         ?  ...         5m (16.5ft) Great White
# 3         9  ...           Suspected Great White
# 10       18  ...                    Undetermined
# 13       40  ...  Undetermined small shall shark
# 20       42  ...                     Great White
# ...     ...  ...                             ...
# 5963     26  ...                             NaN
# 6008    NaN  ...                       12' shark
# 6828    NaN  ...                             NaN
# 6875  young  ...                             NaN
# 6941    NaN  ...                             NaN
#
#                                                  Source  \
# 1     Bob Myatt GSAF The Guardian: 9 News: ABS News:...
# 3                                        Bob Myatt GSAF
# 10    Brandyn Gartelman: Kevin McMurray Trackingshar...
# 13    Todd Smith:Kevin McMurray Trackingsharks.com: ...
# 20                           James Kingsley: The US Sun
# ...                                                 ...
# 5963    The Argus, 1/9/1922; V.M. Coppleson (1933), N15
# 6008                          The Advertiser, 3/25/1918
# 6828          J. Borg, p.68; L. Taylor (1993), pp.94-95
# 6875  G.H. Balazs; J. Borg, p.68; L. Taylor (1993), ...
# 6941                                 M. Vorenberg, GSAF
#
#                               pdf  \
# 1                             NaN
# 3                             NaN
# 10                            NaN
# 13                            NaN
# 20                            NaN
# ...                           ...
# 5963  1922.01.04-JManningRowe.pdf
# 6008          1918.03.22-Cook.pdf
# 6828          1828.00.00-male.pdf
# 6875        1779.00.00-Hawaii.pdf
# 6941               ND-0122-CM.pdf
#
#                                            href formula  \
# 1                                                   NaN
# 3                                                   NaN
# 10                                                  NaN
# 13                                                  NaN
# 20                                                  NaN
# ...                                                 ...
# 5963  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6008  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6828  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6875  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6941  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number  \
# 1                                                   NaN         NaN
# 3                                                   NaN         NaN
# 10                                                  NaN         NaN
# 13                                                  NaN         NaN
# 20                                                  NaN         NaN
# ...                                                 ...         ...
# 5963  http://sharkattackfile.net/spreadsheets/pdf_di...  1922.01.04
# 6008  http://sharkattackfile.net/spreadsheets/pdf_di...  1918.03.22
# 6828  http://sharkattackfile.net/spreadsheets/pdf_di...  1828.00.00
# 6875  http://sharkattackfile.net/spreadsheets/pdf_di...  1779.00.00
# 6941  http://sharkattackfile.net/spreadsheets/pdf_di...     ND-0122
#
#      Case Number.1 original order Unnamed: 21 Unnamed: 22
# 1              NaN            NaN         NaN         NaN
# 3              NaN            NaN         NaN         NaN
# 10             NaN            NaN         NaN         NaN
# 13             NaN            NaN         NaN         NaN
# 20             NaN            NaN         NaN         NaN
# ...            ...            ...         ...         ...
# 5963    1922.01.04         1077.0         NaN         NaN
# 6008    1918.03.22         1032.0         NaN         NaN
# 6828    1828.00.00          212.0         NaN         NaN
# 6875    1779.00.00          166.0         NaN         NaN
# 6941       ND-0122          102.0         NaN         NaN
#
# [1138 rows x 23 columns]

# %%
# Number of attacks to surfing in the USA.
surf_count_usa = usa_filtered_df[usa_filtered_df["Activity"] == "Surfing"].shape[0]
surf_count_usa
# Out:
# 667

# %%
#Percentage of attacks to the USA to surfing over the total number of attacks to surfing.
percentage_usa_surf = f"{((surf_count_usa/surf_count) * 100):.2f}%"
percentage_usa_surf
# Out:
# '58.61%'

# %%
# Filters dataframe with only USA attacks to surfers.
usa_surf = usa_filtered_df[(usa_filtered_df["Country"] == "USA") & (usa_filtered_df["Activity"] == "Surfing")]
usa_surf
# Out:
#      Country       State                                      Location  \
# 2        USA     Florida                              New Smyrna Beach
# 4        USA     Florida                              New Smyrna Beach
# 9        USA  California                           Montara State Beach
# 13       USA     Florida                  Bathtub Beach, Martin County
# 14       USA     Florida                        Brevard County Orlando
# ...      ...         ...                                           ...
# 2023     USA      Hawaii                    Awili, South Kona, Hawai'i
# 2154     USA  California  Zuma Beach, Santa Monica, Los Angeles County
# 2539     USA      Hawaii                             Uo, Lahaina, Maui
# 2547     USA      Hawaii                                Maliu, Hawai'i
# 2557     USA     Florida          Lost Tree Village, Palm Beach County
#
#      Activity
# 2     Surfing
# 4     Surfing
# 9     Surfing
# 13    Surfing
# 14    Surfing
# ...       ...
# 2023  Surfing
# 2154  Surfing
# 2539  Surfing
# 2547  Surfing
# 2557  Surfing
#
# [667 rows x 4 columns]

# %%
# Value counts the attacks in the USA to surfers per state.
usa_surf_states_value = usa_surf.State.value_counts()
usa_surf_states_value
# Out:
# State
# Florida                   421
# California                 87
# Hawaii                     74
# Oregon                     25
# North Carolina             25
# South Carolina             10
# Texas                       9
# New York                    5
# New Jersey                  2
# Georgia                     2
# Noirth Carolina             1
# Franklin CountyFlorida      1
# Guam                        1
# Rhode Island                1
# Washington                  1
# Puerto Rico                 1
# Virginia                    1
# Name: count, dtype: int64

# %%
type(usa_surf_states_value)
# Out:
# pandas.core.series.Series

# %%
# Total attacks in Florida (all activities)
total_florida = df["State"].value_counts().get("Florida", 0)
# Total attacks in Florida when the activity was surfing
total_florida_surfing = df[
    (df["State"] == "Florida") &
    (df["Activity"] == "Surfing")
].shape[0]
# Percentage
if total_florida > 0:
    perc_surfing = (total_florida_surfing / total_florida) * 100
else:
    perc_surfing = 0

print(f"Number of attacks in Florida: {total_florida}")
print(f"Total attacks in Florida when the activity was surfing: {total_florida_surfing}")
print(f"Percentage of attacks in Florida when the activity was surfing over the total attacks in Florida: {perc_surfing:.2f}%")
# Out:
# Number of attacks in Florida: 1191
# Total attacks in Florida when the activity was surfing: 419
# Percentage of attacks in Florida when the activity was surfing over the total attacks in Florida: 35.18%

# %%
# Filters dataframe with only Florida attacks to surfers.
florida_surf_df = usa_filtered_df[(usa_filtered_df["State"] == "Florida") & (usa_filtered_df["Activity"] == "Surfing")]
florida_surf_df
# Out:
#      Country    State                              Location Activity
# 2        USA  Florida                      New Smyrna Beach  Surfing
# 4        USA  Florida                      New Smyrna Beach  Surfing
# 13       USA  Florida          Bathtub Beach, Martin County  Surfing
# 14       USA  Florida                Brevard County Orlando  Surfing
# 39       USA  Florida      New Smyrna Beach, Volusia County  Surfing
# ...      ...      ...                                   ...      ...
# 1948     USA  Florida      Riviera Beach, Palm Beach County  Surfing
# 1957     USA  Florida           Jensen Beach, Martin County  Surfing
# 1959     USA  Florida                     Palm Beach County  Surfing
# 1961     USA  Florida           Jensen Beach, Martin County  Surfing
# 2557     USA  Florida  Lost Tree Village, Palm Beach County  Surfing
#
# [421 rows x 4 columns]

# %%
# Reset the index after filtering.
florida_surf_df.reset_index(drop=True, inplace=True)
florida_surf_df
# Out:
#     Country    State                              Location Activity
# 0       USA  Florida                      New Smyrna Beach  Surfing
# 1       USA  Florida                      New Smyrna Beach  Surfing
# 2       USA  Florida          Bathtub Beach, Martin County  Surfing
# 3       USA  Florida                Brevard County Orlando  Surfing
# 4       USA  Florida      New Smyrna Beach, Volusia County  Surfing
# ..      ...      ...                                   ...      ...
# 416     USA  Florida      Riviera Beach, Palm Beach County  Surfing
# 417     USA  Florida           Jensen Beach, Martin County  Surfing
# 418     USA  Florida                     Palm Beach County  Surfing
# 419     USA  Florida           Jensen Beach, Martin County  Surfing
# 420     USA  Florida  Lost Tree Village, Palm Beach County  Surfing
#
# [421 rows x 4 columns]

# %%
# Value counts the attacks to surfers per Location in Florida.
florida_surf_series = florida_surf_df.Location.value_counts()
florida_surf_series
# Out:
# Location
# New Smyrna Beach, Volusia County                 129
# Ponce Inlet, Volusia County                       19
# Melbourne Beach, Brevard County                   12
# Ponce Inlet, New Smyrna Beach, Volusia County     11
# Cocoa Beach, Brevard  County                       8
#                                                 ...
# Sebastian, Indian River County                     1
# Ormond By The Sea, Volusia County                  1
# Ft. Pierce, St Lucie County                        1
# Matanzas Inlet, St Johns County                    1
# Lost Tree Village, Palm Beach County               1
# Name: count, Length: 153, dtype: int64

# %%
# Checking appearances of New Smyrna Beach in the various locations in Florida.
number_rows_new_smyrna = florida_surf_series.loc[florida_surf_series.index.str.contains("New Smyrna Beach", case=False, na=False)]
number_rows_new_smyrna
# Out:
# Location
# New Smyrna Beach, Volusia County                                            129
# Ponce Inlet, New Smyrna Beach, Volusia County                                11
# New Smyrna Beach                                                              6
# New Smyrna Beach / Waveland, Volusia County                                   2
# South Jetty, New Smyrna Beach, Volusia County                                 2
# New Smyrna Beach / Ponce Inlet, Volusia County                                1
# 1.4 miles south of Ponce de Leon Jetty, New Smyrna Beach, Volusia County      1
# Bethune Beach, south of New Smyrna Beach, Volusia County                      1
# South of Ponce Inlet, New Smyrna Beach, Volusia County                        1
# Name: count, dtype: int64

# %%
# Making a pattern of New Smyrna Beach in the various locations in Florida.
florida_surf_df["Location"] = florida_surf_df["Location"].replace({
   "Ponce Inlet, New Smyrna Beach, Volusia County": "New Smyrna Beach, Volusia County",
    "New Smyrna Beach": "New Smyrna Beach, Volusia County",
    "New Smyrna Beach / Waveland, Volusia County": "New Smyrna Beach, Volusia County",
    "South Jetty, New Smyrna Beach, Volusia County": "New Smyrna Beach, Volusia County",
    "New Smyrna Beach / Ponce Inlet, Volusia County": "New Smyrna Beach, Volusia County",
    "1.4 miles south of Ponce de Leon Jetty, New Smyrna Beach, Volusia County": "New Smyrna Beach, Volusia County",
    "Bethune Beach, south of New Smyrna Beach, Volusia County": "New Smyrna Beach, Volusia County",
    "South of Ponce Inlet, New Smyrna Beach, Volusia County": "New Smyrna Beach, Volusia County"
})
# Out:
# /tmp/ipython-input-2348149365.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   florida_surf_df["Location"] = florida_surf_df["Location"].replace({

# %%
florida_surf_df["Location"]
# Out:
# 0          New Smyrna Beach, Volusia County
# 1          New Smyrna Beach, Volusia County
# 2              Bathtub Beach, Martin County
# 3                    Brevard County Orlando
# 4          New Smyrna Beach, Volusia County
#                        ...
# 416        Riviera Beach, Palm Beach County
# 417             Jensen Beach, Martin County
# 418                       Palm Beach County
# 419             Jensen Beach, Martin County
# 420    Lost Tree Village, Palm Beach County
# Name: Location, Length: 421, dtype: object

# %%
#Counting attacks in New Smyrna Beach.
florida_surf_series = florida_surf_df.Location.value_counts()
florida_surf_series
# Out:
# Location
# New Smyrna Beach, Volusia County        154
# Ponce Inlet, Volusia County              19
# Melbourne Beach, Brevard County          12
# Cocoa Beach, Brevard  County              8
# Daytona Beach, Volusia County             8
#                                        ...
# Sebastian, Indian River County            1
# Ormond By The Sea, Volusia County         1
# Ft. Pierce, St Lucie County               1
# Matanzas Inlet, St Johns County           1
# Lost Tree Village, Palm Beach County      1
# Name: count, Length: 145, dtype: int64

# %%
usa_filtered_df = df[df['Country'].str.strip().str.upper() == "USA"]
usa_filtered_df
# Out:
#                     Date    Year        Type Country            State  \
# 0       16th August 2025  2025.0    Provoked     USA          Florida
# 9              19th July  2025.0  Unprovoked     USA          Florida
# 10             18th July  2025.0  Unprovoked     USA          Florida
# 12             6th July   2025.0    Provoked     USA    Massachusetts
# 13              6th July  2025.0  Unprovoked     USA          Florida
# ...                  ...     ...         ...     ...              ...
# 6989         Before 1958     0.0  Unprovoked     USA          Florida
# 7023         Before 1921     0.0  Unprovoked     USA          Florida
# 7028  Before 17-Jul-1916     0.0  Unprovoked     USA  North Carolina
# 7032          Circa 1862     0.0  Unprovoked     USA           Hawaii
# 7039           1900-1905     0.0  Unprovoked     USA   North Carolina
#
#                                                Location  Activity  \
# 0                                Cayo Costa Boca Grande   Fishing
# 9     Jupiter Inlet off Jupiter Beach Palm Beach County    Diving
# 10                                     New Smyrna Beach   Surfing
# 12                        Hoicks Hollow Nantucket Beach   Fishing
# 13                                     New Smyrna Beach   Surfing
# ...                                                 ...       ...
# 6989                      Palm Beach, Palm Beach County  Standing
# 7023                           Gadsden Point, Tampa Bay   Fishing
# 7028            Somewhere between Hatteras and Beaufort  Swimming
# 7032                                               Puna       NaN
# 7039                                     Ocracoke Inlet  Swimming
#
#                        Name Sex  Age  ...                        Species   \
# 0               Shawn Meuse   M    ?  ...         Lemon shark 1.8 m (6ft)
# 9                 Jeff Joel   M   69  ...                     Lemon shark
# 10               Sam Hollis   M   18  ...                    Undetermined
# 12             Unknown Male   M   21  ...                         Unknown
# 13             Unknown Male   M   40  ...  Undetermined small shall shark
# ...                     ...  ..  ...  ...                             ...
# 6989           Horton Chase   M  NaN  ...                             NaN
# 7023           James Kelley   M  NaN  ...                             NaN
# 7028        "youthful male"   M  NaN  ...                             NaN
# 7032           A "chiefess"   F  NaN  ...                             NaN
# 7039  Coast Guard personnel   M  NaN  ...                             NaN
#
#                                                  Source  \
# 0     Johannes Marchand: Kevin McMurray Trackingshar...
# 9     Brandyn Gartelman: Kevin McMurray Trackingshar...
# 10    Brandyn Gartelman: Kevin McMurray Trackingshar...
# 12                 Johannes Marchand: Nantucket Current
# 13    Todd Smith:Kevin McMurray Trackingsharks.com: ...
# ...                                                 ...
# 6989         V.M. Coppleson (1956), p.255;  R.F. Hutton
# 7023                                     T. Helm, p.219
# 7028     C. Creswell, GSAF; Wilmington Star, 7/17/1916
# 7032                                   Captain W. Young
# 7039               F. Schwartz, p.23; C. Creswell, GSAF
#
#                                     pdf  \
# 0                                   NaN
# 9                                   NaN
# 10                                  NaN
# 12                                  NaN
# 13                                  NaN
# ...                                 ...
# 6989            ND-0056-HortonChase.pdf
# 7023                 ND-0019-Kelley.pdf
# 7028  ND-0014-pre1916-NorthCarolina.pdf
# 7032            ND-0010-Puna Hawaii.pdf
# 7039     ND-0003-Ocracoke_1900-1905.pdf
#
#                                            href formula  \
# 0                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# ...                                                 ...
# 6989  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7023  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7028  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7032  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7039  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number  \
# 0                                                   NaN         NaN
# 9                                                   NaN         NaN
# 10                                                  NaN         NaN
# 12                                                  NaN         NaN
# 13                                                  NaN         NaN
# ...                                                 ...         ...
# 6989  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0056
# 7023  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0019
# 7028  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0014
# 7032  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0010
# 7039  http://sharkattackfile.net/spreadsheets/pdf_di...     ND.0003
#
#      Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0              NaN            NaN         NaN         NaN
# 9              NaN            NaN         NaN         NaN
# 10             NaN            NaN         NaN         NaN
# 12             NaN            NaN         NaN         NaN
# 13             NaN            NaN         NaN         NaN
# ...            ...            ...         ...         ...
# 6989       ND.0056           54.0         NaN         NaN
# 7023       ND.0019           20.0         NaN         NaN
# 7028       ND.0014           15.0         NaN         NaN
# 7032       ND.0010           11.0         NaN         NaN
# 7039       ND.0003            4.0         NaN         NaN
#
# [2570 rows x 23 columns]

# %%
import seaborn as sns

# %%
# Get top 3 activities by attacks
top_activities = df['Activity'].value_counts().nlargest(3).index

# Filter dataframe
df_top_activities = df[df['Activity'].isin(top_activities)]

# Plot
sns.countplot(x='Activity', data=df_top_activities)
# Out:
# <Axes: xlabel='Activity', ylabel='count'>

# %%
# Get top 3 countries by attacks when surfing
top_countries = surf_count_df['Country'].value_counts().nlargest(3).index

# Filter dataframe
surf_count_df_top = surf_count_df[surf_count_df['Country'].isin(top_countries)]

# Plot
sns.countplot(x='Country', data=surf_count_df_top)
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
# Get top 3 states by frequency when activity was surfing
top_usa_states_surf = usa_surf['State'].value_counts().nlargest(3).index

# Filter dataframe
df_top_states_surf = usa_surf[usa_surf['State'].isin(top_usa_states_surf)]

# Plot
sns.countplot(x='State', data=df_top_states_surf)
# Out:
# <Axes: xlabel='State', ylabel='count'>

# %%
import matplotlib.pyplot as plt

# %%
# Get top 3 locations by frequency when activity was surfing
top_florida_locations_surf = florida_surf_df['Location'].value_counts().nlargest(3).index

# Filter dataframe
df_top_locations_surf = florida_surf_df[florida_surf_df['Location'].isin(top_florida_locations_surf)]

# Plot
sns.countplot(x='Location', data=df_top_locations_surf)
plt.xticks(rotation=45, ha='right')
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'New Smyrna Beach, Volusia County'),
#   Text(1, 0, 'Ponce Inlet, Volusia County'),
#   Text(2, 0, 'Melbourne Beach, Brevard County')])
